# %%
import numpy as np

a = np.arange(8)
b = a[4:6]
b[:] = 40
c = a[4] + a[6]
c
# Out:
# 46

# %%
import re
s = 'ABCAC'
bool(re.match('A', s))
#len(re.split('A', s))
#len(re.search('A', s))
#re.match('A', s) == True
# Out:
# True

# %%
def result():
    s = 'ACAABAACAAABACDBADDDFSDDDFFSSSASDAFAAACBAAAFASD'

    result = []
    # compete the pattern below
    pattern = "([^A])(?=A{3})"
    for item in re.finditer(pattern, s):
      # identify the group number below.
      result.append(item.group())
      
    return result
result()
# Out:
# ['C', 'F', 'B']

# %%
import pandas as pd
df = pd.Series({'d':4,'b':7,'a':-5,'c':3})
df
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
print(df.iloc[0])
print(df['d'])
print(df[0])
print(df.index[0])
# Out:
# 4
# 4
# 4
# d

# %%
s1=pd.Series([20,15,18,31],index=['Mango','Strawberry','Blueberry','Vanilla'])
s2=pd.Series([20,30,15,20,20],index=['Strawberry','Venilla','Banana','Mango','Plain'])
s3 = s1.add(s2)
s3
# Out:
# Banana         NaN
# Blueberry      NaN
# Mango         40.0
# Plain          NaN
# Strawberry    35.0
# Vanilla        NaN
# Venilla        NaN
# dtype: float64

# %%
s3['Blueberry'] == s1['Blueberry']
# Out:
# False

# %%
s3['Blueberry'] == s1.add(s2, fill_value = 0)['Blueberry']
# Out:
# False

# %%
s3['Plain'] >= s3['Mango']
# Out:
# False

# %%
s3['Mango'] >=  s1.add(s2, fill_value = 0)['Mango']
# Out:
# True

# %%
df=pd.DataFrame(np.random.randint(0,10,25).reshape(5,5),columns=['Q','W','E','R','T'])
df.set_index(['Q'])
# Out:
#    W  E  R  T
# Q
# 4  2  2  2  8
# 2  9  7  3  6
# 8  2  1  7  9
# 5  7  9  8  6
# 5  6  9  3  0

# %%
df.set_index('T')
# Out:
#    Q  W  E  R
# T
# 8  4  2  2  2
# 6  2  9  7  3
# 9  8  2  1  7
# 6  5  7  9  8
# 0  5  6  9  3

# %%
df.reset_index()
# Out:
#    index  Q  W  E  R  T
# 0      0  4  2  2  2  8
# 1      1  2  9  7  3  6
# 2      2  8  2  1  7  9
# 3      3  5  7  9  8  6
# 4      4  5  6  9  3  0

# %%
S = pd.Series(np.arange(5), index=['a', 'b', 'c', 'd', 'e'])
S
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int32

# %%
S['b':'e']
# Out:
# b    1
# c    2
# d    3
# e    4
# dtype: int32

# %%
S[['b', 'c', 'd']]
# Out:
# b    1
# c    2
# d    3
# dtype: int32

# %%
S[S <= 3][S > 0]
# Out:
# b    1
# c    2
# d    3
# dtype: int32

# %%
S[1:4]
# Out:
# b    1
# c    2
# d    3
# dtype: int32

# %%
df=pd.DataFrame(np.array([[5,6,20],[5,82,28],[71,31,92],[67,37,49]]),columns=['a','b','c'],index=['R1','R2','R3','R4'])
df
# Out:
#      a   b   c
# R1   5   6  20
# R2   5  82  28
# R3  71  31  92
# R4  67  37  49

# %%
f = lambda x: x.max() + x.min()
df_new = df.apply(f)
df_new
# Out:
# a     76
# b     88
# c    112
# dtype: int64

# %%
df_new[1]
# Out:
# 88

# %%
df = pd.read_csv('../week3/datasets/cwurData.csv')
def create_category(ranking):
    # Since the rank is just an integer, I'll just do a bunch of if/elif statements
    if (ranking >= 1) & (ranking <= 100):
        return "First Tier Top Unversity"
    elif (ranking >= 101) & (ranking <= 200):
        return "Second Tier Top Unversity"
    elif (ranking >= 201) & (ranking <= 300):
        return "Third Tier Top Unversity"
    return "Other Top Unversity"

# Now we can apply this to a single column of data to create a new series
df['Rank_Level'] = df['world_rank'].apply(lambda x: create_category(x))
# And lets look at the result

df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.mean, np.max],margins=True).head()
# Out:
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN           44.672857
# Australia                   47.9425           44.645750
# Austria                         NaN           44.864286
# Belgium                     51.8750           45.081000
# Brazil                          NaN           44.499706
#
#                                                                           \
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity        All
# country
# Argentina                        NaN                      NaN  44.672857
# Australia                    49.2425                47.285000  45.825517
# Austria                          NaN                47.066667  45.139583
# Belgium                      49.0840                46.746667  47.011000
# Brazil                       49.5650                      NaN  44.781111
#
# ...

# %%
new_df=df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.mean, np.max],margins=True)
new_df.head()
# Out:
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN           44.672857
# Australia                   47.9425           44.645750
# Austria                         NaN           44.864286
# Belgium                     51.8750           45.081000
# Brazil                          NaN           44.499706
#
#                                                                           \
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity        All
# country
# Argentina                        NaN                      NaN  44.672857
# Australia                    49.2425                47.285000  45.825517
# Austria                          NaN                47.066667  45.139583
# Belgium                      49.0840                46.746667  47.011000
# Brazil                       49.5650                      NaN  44.781111
#
# ...

# %%
new_df.unstack().unstack()
# Out:
# country                         Argentina  Australia    Austria    Belgium  \
#      Rank_Level
# mean First Tier Top Unversity         NaN  47.942500        NaN  51.875000
#      Other Top Unversity        44.672857  44.645750  44.864286  45.081000
#      Second Tier Top Unversity        NaN  49.242500        NaN  49.084000
#      Third Tier Top Unversity         NaN  47.285000  47.066667  46.746667
#      All                        44.672857  45.825517  45.139583  47.011000
# amax First Tier Top Unversity         NaN  51.610000        NaN  52.030000
#      Other Top Unversity        45.660000  45.970000  46.290000  46.210000
#      Second Tier Top Unversity        NaN  50.400000        NaN  49.730000
#      Third Tier Top Unversity         NaN  47.470000  47.780000  47.140000
#      All                        45.660000  51.610000  47.780000  52.030000
#
# country                            Brazil  Bulgaria     Canada    Chile  \
#      Rank_Level
# ...

# %%
df=pd.DataFrame({'Item':['item_1','item_1','item_1','item_2','item_2','item_2'],'Store':['A','B','C','A','B','C'],'Quantity sold':[10.0,20.0,np.nan,5.0,10.0,15.0]})
df
# Out:
#      Item Store  Quantity sold
# 0  item_1     A           10.0
# 1  item_1     B           20.0
# 2  item_1     C            NaN
# 3  item_2     A            5.0
# 4  item_2     B           10.0
# 5  item_2     C           15.0

# %%
df.groupby('Item').sum().iloc[0]['Quantity sold']
# Out:
# 30.0
